# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Wellbeing_and_lifestyle_data_Kaggle.csv")
data
# Out:
#           Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 0            7/7/15               3            2               2            5
# 1            7/7/15               2            3               4            3
# 2            7/7/15               2            3               3            4
# 3            7/7/15               3            3              10            3
# 4            7/7/15               5            1               3            3
# ...             ...             ...          ...             ...          ...
# 15967  3/14/21 5:42               3            3               0            4
# 15968  3/14/21 6:30               3            3               6            8
# 15969  3/14/21 8:35               4            3               0           10
# 15970  3/14/21 8:43               1            1              10            8
# 15971  3/14/21 9:03               5            4               0            2
#
# ...

# %%
data.shape #(rows, columns)
# Out:
# (15972, 24)

# %%
data.head()
# Out:
#   Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 0    7/7/15               3            2               2            5
# 1    7/7/15               2            3               4            3
# 2    7/7/15               2            3               3            4
# 3    7/7/15               3            3              10            3
# 4    7/7/15               5            1               3            3
#
#    SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  ...  \
# 0                  0               5            2         0          1  ...
# 1                  8              10            5         2          2  ...
# 2                  4              10            3         2          2  ...
# 3                 10               7            2         5          2  ...
# 4                 10               4            2         4          2  ...
#
#    SLEEP_HOURS  LOST_VACATION  DAILY_SHOUTING  SUFFICIENT_INCOME  \
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'FRUITS_VEGGIES', 'DAILY_STRESS', 'PLACES_VISITED',
#        'CORE_CIRCLE', 'SUPPORTING_OTHERS', 'SOCIAL_NETWORK', 'ACHIEVEMENT',
#        'DONATION', 'BMI_RANGE', 'TODO_COMPLETED', 'FLOW', 'DAILY_STEPS',
#        'LIVE_VISION', 'SLEEP_HOURS', 'LOST_VACATION', 'DAILY_SHOUTING',
#        'SUFFICIENT_INCOME', 'PERSONAL_AWARDS', 'TIME_FOR_PASSION',
#        'WEEKLY_MEDITATION', 'AGE', 'GENDER', 'WORK_LIFE_BALANCE_SCORE'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                            count        mean        std    min    25%    50%  \
# FRUITS_VEGGIES           15972.0    2.922677   1.442694    0.0    2.0    3.0
# PLACES_VISITED           15972.0    5.232970   3.311912    0.0    2.0    5.0
# CORE_CIRCLE              15972.0    5.508077   2.840334    0.0    3.0    5.0
# SUPPORTING_OTHERS        15972.0    5.616454   3.242021    0.0    3.0    5.0
# SOCIAL_NETWORK           15972.0    6.474267   3.086672    0.0    4.0    6.0
# ACHIEVEMENT              15972.0    4.000751   2.755837    0.0    2.0    3.0
# DONATION                 15972.0    2.715314   1.851586    0.0    1.0    3.0
# BMI_RANGE                15972.0    1.410656   0.491968    1.0    1.0    1.0
# TODO_COMPLETED           15972.0    5.745993   2.624097    0.0    4.0    6.0
# FLOW                     15972.0    3.194778   2.357518    0.0    1.0    3.0
# DAILY_STEPS              15972.0    5.703606   2.891013    1.0    3.0    5.0
# ...

# %%
data.describe(exclude = "number").T
# Out:
#               count unique       top  freq
# Timestamp     15972   7002   7/23/18   162
# DAILY_STRESS  15972      7         3  4398
# AGE           15972      4  21 to 35  6108
# GENDER        15972      2    Female  9858

# %% [markdown]
# ## Initial Thoughts
# - Most of the columns are in numeric veriables
# - Only 4 columns are in non-numeric veriables
# - 'DAILY_STRESS' column seems like to contain numberic variables but it is not. Since I need to use this column, I may need to think about how to analyse this column with other columns with numeric variables

# %%
data.DAILY_STRESS.unique()
# Out:
# array(['2', '3', '1', '4', '5', '0', '1/1/00'], dtype=object)

# %%
data_cleaned = data.drop(['Timestamp', 'FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE', 'SUPPORTING_OTHERS', 
                          'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'BMI_RANGE', 'TODO_COMPLETED', 'DAILY_STEPS',
                          'LIVE_VISION', 'SLEEP_HOURS', 'LOST_VACATION', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS', 
                          'TIME_FOR_PASSION', 'AGE', 'GENDER', 'WORK_LIFE_BALANCE_SCORE'], axis = "columns")
data_cleaned
# Out:
#       DAILY_STRESS  FLOW  DAILY_SHOUTING  WEEKLY_MEDITATION
# 0                2     4               5                  5
# 1                3     2               2                  6
# 2                3     2               2                  3
# 3                3     5               5                  0
# 4                1     0               0                  5
# ...            ...   ...             ...                ...
# 15967            3     2               1                  5
# 15968            3     5               0                  8
# 15969            3     3               1                 10
# 15970            1    10               2                  8
# 15971            4     4               2                  4
#
# [15972 rows x 4 columns]

# %%
data_cleaned = data_cleaned.dropna()
data_cleaned
# Out:
#       DAILY_STRESS  FLOW  DAILY_SHOUTING  WEEKLY_MEDITATION
# 0                2     4               5                  5
# 1                3     2               2                  6
# 2                3     2               2                  3
# 3                3     5               5                  0
# 4                1     0               0                  5
# ...            ...   ...             ...                ...
# 15967            3     2               1                  5
# 15968            3     5               0                  8
# 15969            3     3               1                 10
# 15970            1    10               2                  8
# 15971            4     4               2                  4
#
# [15972 rows x 4 columns]

# %% [markdown]
# * There is no missing value

# %%
not_stress_levels = ['1/1/00']
data_cleaned = data_cleaned[data_cleaned.DAILY_STRESS.isin(not_stress_levels) == False]
data_cleaned['DAILY_STRESS'].unique()
# Out:
# array(['2', '3', '1', '4', '5', '0'], dtype=object)

# %% [markdown]
# * Dropped a row which contain invalid value - '1/1/00'.

# %%
data_cleaned = data_cleaned.reset_index()
data_cleaned = data_cleaned.drop(['index'], axis = 'columns')
data_cleaned
# Out:
#       DAILY_STRESS  FLOW  DAILY_SHOUTING  WEEKLY_MEDITATION
# 0                2     4               5                  5
# 1                3     2               2                  6
# 2                3     2               2                  3
# 3                3     5               5                  0
# 4                1     0               0                  5
# ...            ...   ...             ...                ...
# 15966            3     2               1                  5
# 15967            3     5               0                  8
# 15968            3     3               1                 10
# 15969            1    10               2                  8
# 15970            4     4               2                  4
#
# [15971 rows x 4 columns]

# %% [markdown]
# * Reset the index and dropped old index column.

# %%
plot1 = sns.catplot(data = data_cleaned, kind = 'bar', x = "WEEKLY_MEDITATION", y = "DAILY_STRESS", order = ['0', '1', '2', '3', '4', '5'])

# %% [markdown]
# * Lower stress levels have higher mean of amount of weekly meditation

# %%
plot2 = sns.catplot(data = data_cleaned, kind = 'bar', x = "FLOW", y = "DAILY_STRESS", order = ['0', '1', '2', '3', '4', '5'])

# %%
plot3 = sns.catplot(data = data_cleaned, kind = 'bar', x = "DAILY_SHOUTING", y = "DAILY_STRESS", order = ['5', '4', '3', '2', '1', '0'])

# %%
plt.subplot(1, 3, 1)
sns.catplot(data = data_cleaned, kind = 'bar', x = "WEEKLY_MEDITATION", y = "DAILY_STRESS", order = ['0', '1', '2', '3', '4', '5'])

plt.subplot(1, 3, 2)
sns.catplot(data = data_cleaned, kind = 'bar', x = "FLOW", y = "DAILY_STRESS", order = ['0', '1', '2', '3', '4', '5'])

plt.subplot(1, 3, 3)
sns.catplot(data = data_cleaned, kind = 'bar', x = "DAILY_SHOUTING", y = "DAILY_STRESS", order = ['5', '4', '3', '2', '1', '0'])

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True)
sns.catplot(data = data_cleaned, kind = 'bar', x = "WEEKLY_MEDITATION", y = "DAILY_STRESS", order = ['0', '1', '2', '3', '4', '5'], ax=ax1)
sns.catplot(data = data_cleaned, kind = 'bar', x = "FLOW", y = "DAILY_STRESS", order = ['0', '1', '2', '3', '4', '5'], ax=ax2)
sns.catplot(data = data_cleaned, kind = 'bar', x = "DAILY_SHOUTING", y = "DAILY_STRESS", order = ['5', '4', '3', '2', '1', '0'], ax=ax3)
# Out:
# /Users/geumailie/miniconda3/lib/python3.10/site-packages/seaborn/categorical.py:3025: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)
# /Users/geumailie/miniconda3/lib/python3.10/site-packages/seaborn/categorical.py:3025: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)
# /Users/geumailie/miniconda3/lib/python3.10/site-packages/seaborn/categorical.py:3025: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)

# %%
g = sns.catplot(x='year', y='income', data=df, kind='bar', hue='geo_name', legend=True)
g.fig.set_size_inches(15, 8)
g.fig.subplots_adjust(top=0.81, right=0.86)

# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')
